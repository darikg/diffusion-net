# %%
ok_channels = {
    9: [0, 2, 23, 29, 31],
    20: [2, 3, 8, 11, 23, 24, 28, 29, 30, 31],
    38: [13, 14, 17, 18, 29, 31],
    48: [11, 13, 20],
    51: [0, 14, 31],
}

# %%
for run_id, channels in ok_channels.items():
    print(run_id, channels)
# Out:
# 9 [0, 2, 23, 29, 31]
# 20 [2, 3, 8, 11, 23, 24, 28, 29, 30, 31]
# 38 [13, 14, 17, 18, 29, 31]
# 48 [11, 13, 20]
# 51 [0, 14, 31]
